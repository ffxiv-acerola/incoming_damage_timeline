# %%
import polars as pl
from dotenv import dotenv_values

import fights
from main import IncomingDamage

pl.config.Config.set_tbl_rows(80)
# Out:
# polars.config.Config

# %%
CONFIG = dotenv_values(".env")
FFLOGS_TOKEN = CONFIG["FFLOGS_TOKEN"]

# %%
logs = {
    "m9n": {"report_id": "2ajHBbTkpRfFxMJg", "fight_id": 5, "party_damage": fights.M9N},
    "m10n": {
        "report_id": "KLypxHcraTdRzY7F",
        "fight_id": 3,
        "party_damage": fights.M10N,
    },
    "m11n": {
        "report_id": "vN4py2QhT91XKLHW",
        "fight_id": 55,
        "party_damage": fights.M11N,
    },
    "m12n": {
        "report_id": "YCLr1Aj6FJ4yQXNH",
        "fight_id": 23,
        "party_damage": fights.M12N,
    },
}

# %%
fight = "m11n"

report_id = logs[fight]["report_id"]
fight_id = logs[fight]["fight_id"]

# Use the updated fight schema
party_damage = logs[fight]["party_damage"]

# %%
incoming_damage = IncomingDamage(
    party_damage,
    report_id=logs[fight]["report_id"],
    fight_id=logs[fight]["fight_id"],
    token=FFLOGS_TOKEN,
)

# %%
incoming_damage.get_damaging_ability_names_and_ids()
# Out:
# shape: (29, 3)
# ┌───────────────────────┬────────────┬────────────────┐
# │ ability_name          ┆ ability_id ┆ damage_type_id │
# │ ---                   ┆ ---        ┆ ---            │
# │ str                   ┆ i64        ┆ i64            │
# ╞═══════════════════════╪════════════╪════════════════╡
# │ Attack                ┆ 46005      ┆ 128            │
# │ Crown of Arcadia      ┆ 46006      ┆ 128            │
# │ Smashdown             ┆ 46011      ┆ 128            │
# │ Smashdown             ┆ 46013      ┆ 128            │
# │ Smashdown             ┆ 46015      ┆ 128            │
# │ Raw Steel             ┆ 46017      ┆ 128            │
# │ Impact                ┆ 46018      ┆ 128            │
# │ Comet                 ┆ 46025      ┆ 1024           │
# │ Cometite              ┆ 46026      ┆ 1024           │
# │ Comet                 ┆ 46027      ┆ 1024           │
# │ Assault Evolved       ┆ 46031      ┆ 128            │
# │ Assault Evolved       ┆ 46032      ┆ 128            │
# │ Dance of Domination   ┆ 46034      ┆ 128            │
# │ Explosion             ┆ 46035      ┆ 1024           │
# │ Dance of Domination   ┆ 46036      ┆ 128            │
# │ One and Only          ┆ 46044      ┆ 128            │
# │ Cosmic Kiss           ┆ 46046      ┆ 128            │
# │ Foregone Fatality     ┆ 46048      ┆ 1024           │
# │ Unmitigated Explosion ┆ 46049      ┆ 1024           │
# │ Massive Meteor        ┆ 46051      ┆ 1024           │
# │ Shockwave             ┆ 46054      ┆ 1024           │
# │ Majestic Meteor       ┆ 46058      ┆ 1024           │
# │ Majestic Meteorain    ┆ 46059      ┆ 1024           │
# │ Mammoth Meteor        ┆ 46060      ┆ 1024           │
# │ Explosion             ┆ 46061      ┆ 1024           │
# │ Fire and Fury         ┆ 46073      ┆ 128            │
# │ Heartbreak Kick       ┆ 46080      ┆ 1024           │
# │ Dance of Domination   ┆ 47081      ┆ 128            │
# │ Flatliner             ┆ 47759      ┆ 128            │
# └───────────────────────┴────────────┴────────────────┘

# %%
party_damage_agg = incoming_damage.get_incoming_damage_profile()

party_damage_agg.select(
    "formatted_time", "ability_name", "unmitigatedAmount", "description", "damage_type"
)
# Out:
# shape: (34, 5)
# ┌────────────────┬─────────────────────┬───────────────────┬────────────────────────┬─────────────┐
# │ formatted_time ┆ ability_name        ┆ unmitigatedAmount ┆ description            ┆ damage_type │
# │ ---            ┆ ---                 ┆ ---               ┆ ---                    ┆ ---         │
# │ str            ┆ str                 ┆ i64               ┆ str                    ┆ str         │
# ╞════════════════╪═════════════════════╪═══════════════════╪════════════════════════╪═════════════╡
# │ 00:11.535      ┆ Crown of Arcadia    ┆ 104289            ┆ Raidwide               ┆ Physical    │
# │ 01:00.477      ┆ Comet               ┆ 38888             ┆ Spread puddle          ┆ Magical     │
# │ 01:02.569      ┆ Comet               ┆ 40509             ┆ Spread puddle          ┆ Magical     │
# │ 01:04.617      ┆ Comet               ┆ 40000             ┆ Spread puddle          ┆ Magical     │
# │ 02:36.985      ┆ Dance of Domination ┆ 24281             ┆ Multi hit slashy slash ┆ Physical    │
# │ 02:37.563      ┆ Dance of Domination ┆ 11034             ┆ Multi hit slashy slash ┆ Physical    │
# │ 02:38.144      ┆ Dance of Domination ┆ 12066             ┆ Multi hit slashy slash ┆ Physical    │
# │ 02:39.300      ┆ Dance of Domination ┆ 73348             ┆ Multi hit slashy slash ┆ Physical    │
# │ 02:45.492      ┆ Explosion           ┆ 112519            ┆ Knockup                ┆ Magical     │
# │ 03:01.132      ┆ Impact              ┆ 97813             ┆ Spread puddle          ┆ Physical    │
# │ 04:11.199      ┆ One and Only        ┆ 108152            ┆ Raidwide ult           ┆ Physical    │
# │ 04:31.908      ┆ Cosmic Kiss         ┆ 13502             ┆ Meteor tower           ┆ Physical    │
# │ 04:31.951      ┆ Cosmic Kiss         ┆ 14563             ┆ Meteor tower           ┆ Physical    │
# │ 05:33.554      ┆ Flatliner           ┆ 103820            ┆ Knockup                ┆ Physical    │
# │ 06:00.162      ┆ Mammoth Meteor      ┆ 97946             ┆ Proximity damage       ┆ Magical     │
# │ 06:00.229      ┆ Mammoth Meteor      ┆ 22540             ┆ Proximity damage       ┆ Magical     │
# │ 06:11.656      ┆ Explosion           ┆ 22132             ┆ Knockup                ┆ Magical     │
# │ 06:11.701      ┆ Explosion           ┆ 22290             ┆ Knockup                ┆ Magical     │
# │ 06:11.745      ┆ Explosion           ┆ 24238             ┆ Knockup                ┆ Magical     │
# │ 06:31.567      ┆ Mammoth Meteor      ┆ 22326             ┆ Proximity damage       ┆ Magical     │
# │ 06:31.612      ┆ Mammoth Meteor      ┆ 21976             ┆ Proximity damage       ┆ Magical     │
# │ 06:42.185      ┆ Explosion           ┆ 20854             ┆ Knockup                ┆ Magical     │
# │ 07:07.426      ┆ Crown of Arcadia    ┆ 99983             ┆ Raidwide               ┆ Physical    │
# │ 07:28.168      ┆ Heartbreak Kick     ┆ 158930            ┆ Multi hit tower        ┆ Magical     │
# │ 07:41.409      ┆ Heartbreak Kick     ┆ 51780             ┆ Multi hit tower        ┆ Magical     │
# │ 07:43.412      ┆ Heartbreak Kick     ┆ 54566             ┆ Multi hit tower        ┆ Magical     │
# │ 07:45.415      ┆ Heartbreak Kick     ┆ 54333             ┆ Multi hit tower        ┆ Magical     │
# │ 07:47.420      ┆ Heartbreak Kick     ┆ 53338             ┆ Multi hit tower        ┆ Magical     │
# │ 08:21.713      ┆ Mammoth Meteor      ┆ 22175             ┆ Proximity damage       ┆ Magical     │
# │ 08:21.735      ┆ Mammoth Meteor      ┆ 21931             ┆ Proximity damage       ┆ Magical     │
# │ 08:40.673      ┆ Comet               ┆ 40664             ┆ Spread puddle          ┆ Magical     │
# │ 08:42.769      ┆ Comet               ┆ 38727             ┆ Spread puddle          ┆ Magical     │
# │ 08:44.820      ┆ Comet               ┆ 38573             ┆ Spread puddle          ┆ Magical     │
# │ 08:44.822      ┆ Comet               ┆ 38017             ┆ Spread puddle          ┆ Magical     │
# └────────────────┴─────────────────────┴───────────────────┴────────────────────────┴─────────────┘

# %%
fig = incoming_damage.plot_party_damage("m11n")
fig.show()

# %%
fig = incoming_damage.plot_tank_damage("m11n", color_by_target=True)
fig.show()
